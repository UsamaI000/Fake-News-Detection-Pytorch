# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "./drive/My Drive/Fake Detection/" "./"

# %%
# !cd './Fake Detection/' && python train.py

# %%
# !cp -r "./Fake Detection" "./drive/My Drive/"
